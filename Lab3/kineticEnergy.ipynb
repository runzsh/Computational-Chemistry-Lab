# %%
import numpy as np
import math

# %%
# data = []
# with open('PROBLEM1.data') as fp:
#     for l in fp.readlines()[2:]:
#         xyz = l.split()[1:]
#         x, y, z = float(xyz[0]), float(xyz[1]), float(xyz[2])
#         data.append(x, y, z)
# data

# %%
# dat = np.loadtxt("PROBLEM1.data", usecols = [1, ])
# dat

# %%
# mass = np.ones(len(dat))
# mass

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
address = "/content/drive/My Drive/Colab Notebooks/MD/PROBLEM1.data"

# %%
def readVelo(fileAddress):
    txt = open(fileAddress, "r")

    velocities = []

    for x in txt:
        # print(x)
        if x[0] != "#":
            temp = x.split()
            velocity = np.array([float(temp[1]), float(temp[2]), float(temp[3])])
            # print(velocity)
            velocities.append(velocity)

    return velocities

arr = readVelo(address)

# %%
def KE(mass, velocities):
    sum = 0;
    for velocity in velocities:
        for v in velocity:
            sum += 0.5*mass*(v**2)

    return sum

# %%
TKE = KE(1, arr)
print("The Total Energy of System of N Particles: ", TKE)
# Out:
# The Total Energy of System of N Particles:  16.996350000000003
