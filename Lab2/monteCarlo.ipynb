# %%
import random
import numpy as np

# stating the number of random points to consider
N = 10000000

# count will store the number of random points
# that fell within the unit circle
count = 0
         
# looping till N, each time taking a random point
# and running checks whether it lies under curve
for i in range(N):
    x = random.random()
    y = random.random()

    if x**2 + y**2 < 1:
        count += 1

# printing the numerically estimated value of pi
pi_est = 4.0*count/N
print(pi_est)

# percentage relative error
pre = abs(np.pi - pi_est)*100/np.pi
print(pre)
# Out:
# 3.1417752
# 0.0058106327056245

# %%
import random
import numpy as np

# stating the number of random points to consider
N = 1000000

# count will store the number of random points
# that fell within the unit circle
count = 0
         
# looping till N, each time taking a random point
# and running checks whether it lies under curve
for i in range(N):
    x = random.uniform(0.0, np.pi/2)
    y = random.uniform(0.0, 1.0)

    if y <= np.sin(x):
        count += 1

# printing the numerically estimated value of pi
sin_est = (np.pi/2)*count/N
print(sin_est)

# percentage relative error
pre = abs(1 - sin_est)*100
print(pre)
# Out:
# 0.9995731009632788
# 0.042689903672121776

# %%
import random
import math
import numpy as np

# stating the number of random points to consider
N = 100000

# length of the 1D box
L = 10
pi = np.pi
fmax = (2/L)

def f(x):
    return fmax*((np.sin(pi*x/L))**2)

# count will store the number of random points lied under the curve
count = 0
         
# looping till N, each time taking a random point
# and running checks whether it lies under curve
for i in range(N):
    x = random.uniform(0.0, L)
    y = random.uniform(0.0, fmax)

    if y <= f(x):
        count += 1

# printing the numerically estimated value of pi
fn_est = (L*fmax)*count/N

print("fmax :", fmax)
print("Area of reactangle: ", L*fmax)
print("Number of points lied under curve: ", count)
print("Ratio: ", count/N)
print("Estimated Area under curve: ", fn_est)

# # percentage relative error
# pre = abs(1 - fn_est)*100
# print(pre)
# Out:
# fmax : 0.2
# Area of reactangle:  2.0
# Number of points lied under curve:  50008
# Ratio:  0.50008
# Estimated Area under curve:  1.00016

# %%
import numpy as np
import matplotlib.pyplot as plt

# defining the function to be calculated
"""
def f(x):
    return np.sin(x)
"""

def definite_integral_show(f, x0, x1, N):
    """
    Approximate the definite integral of f(x)dx between bounds x0 and x1 using
    N random points

    Arguements passed:
    f -- a function of one variable
    N -- number of random points to use
    
    """

    # First we are calculating fmax in the range x0 to x1
    # We do it by evaluating f(x) on a grid of points between x0 and x1
    # Here we are assuming the function is differentiable throughout the interval
    x = np.arange(x0, x1, 0.001)
    y = f(x)
    f_max = max(y)


    # Generating Random points:
    # x0 <= x <= x1
    # Creating random points between 0 and 1, then multiplying it with x1-x0 and adding with x0
    # 0 <= y <= f_max
    x_rand = x0 + np.random.random(N)*(x1 - x0)
    y_rand = 0 + np.random.random(N)*f_max


    # Categorizing points between below the curve or above the curve
    ind_below = np.where(y_rand < f(x_rand))
    ind_above = np.where(y_rand >= f(x_rand))


    # Ploting the Result
    plt.plot(x, y, color = "red")
    pts_below = plt.scatter(x_rand[ind_below], y_rand[ind_below], color = "green")
    pts_above = plt.scatter(x_rand[ind_above], y_rand[ind_above], color = "blue")
    plt.legend((pts_below, pts_above), ('Pts below the curve', 'Pts above the curve'), loc = 'lower left', ncol = 3, fontsize = 8)


    # Printing the Result
    print("Number of points above the curve:", len(ind_above[0]))
    print("Number of points below the curve:", len(ind_below[0]))
    print("N.below/N.total:", len(ind_below[0])/N)
    print("Rectangle area:", f_max*(x1-x0))
    print("Area under the curve:", f_max*(x1-x0)*len(ind_below[0])/N)

# %%
def f1(x):
    return np.sqrt(1 - x**2)

definite_integral_show(f1, 0, 1, 200)
# Out:
# Number of points above the curve: 47
# Number of points below the curve: 153
# N.below/N.total: 0.765
# Rectangle area: 1.0
# Area under the curve: 0.765

# %%
def g(x):
    return np.cos(x)

definite_integral_show(g, 0, np.pi/2, 10000)
# Out:
# Number of points above the curve: 3694
# Number of points below the curve: 6306
# N.below/N.total: 0.6306
# Rectangle area: 1.5707963267948966
# Area under the curve: 0.9905441636768617

# %%
def f(x):
    return np.sin(x)

definite_integral_show(f, 0, np.pi/2, 1000)
# Out:
# Number of points above the curve: 350
# Number of points below the curve: 650
# N.below/N.total: 0.65
# Rectangle area: 1.570795828745387
# Area under the curve: 1.0210172886845015

# %%
def definite_integral(f, x0, x1, N):
    """
    Approximate the definite integral of f(x)dx between bounds x0 and x1 using
    N random points

    Arguements passed:
    f -- a function of one variable
    N -- number of random points to use
    
    """

    # First we are calculating fmax in the range x0 to x1
    # We do it by evaluating f(x) on a grid of points between x0 and x1
    # Here we are assuming the function is differentiable throughout the interval
    x = np.arange(x0, x1, 0.001)
    y = f(x)
    f_max = max(y)


    # Generating Random points:
    # x0 <= x <= x1
    # Creating random points between 0 and 1, then multiplying it with x1-x0 and adding with x0
    # 0 <= y <= f_max
    x_rand = x0 + np.random.random(N)*(x1 - x0)
    y_rand = 0 + np.random.random(N)*f_max


    # Categorizing points between below the curve or above the curve
    ind_below = np.where(y_rand < f(x_rand))
    ind_above = np.where(y_rand >= f(x_rand))


    # Returning the Result
    return f_max*(x1-x0)*len(ind_below[0])/N

# %%
# Calculating Monte Carlo for n times
n = 1000
def f(x):
    return np.sin(x)
a = np.zeros(1000, np.float64)
for i in range(n):
    a[i] = definite_integral(f, 0, np.pi/2, 1000)

# %%
# Calculating mathematical pointers
mean = np.mean(a)
median = np.median(a)
std_dev = np.std(a)

mae = 0
for i in range(1000):
    mae = mae + abs(a[i] - 1)
mae = mae/1000

print("Mean: ", mean)
print("Median: ", median)
print("Standard Deviation: ", std_dev)
print("Mean Absolute Error: ", mae)
# Out:
# Mean:  1.0007948631852335
# Median:  1.0005969429108115
# Standard Deviation:  0.023692794362519694
# Mean Absolute Error:  0.0188559594398601

# %%
# Creating a stack of two columns, representing iterations and predicted values
arr = np.arange(0, 1000, 1)
arr = np.vstack((arr, a)).T

# Creating a plot using matplotlib.pyplot library
marker_size = 8
plt.scatter(arr[:,0], arr[:,1], marker_size, c = 'r')
plt.title("Monte Carlo Integration of sin(x)dx")
plt.xlabel("Iteration")
plt.ylabel("Predicted Value")
plt.show()

# %%
# Explicit calculation of standard deviation
sum = 0
for i in range(1000):
    sum = sum + (a[i] - mean)**2

sd = np.sqrt(sum/n)
print(sd)
# Out:
# 0.024113548257981437
